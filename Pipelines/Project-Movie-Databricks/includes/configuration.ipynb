# %% [markdown]
# ###Accediendo a los contenedores

# %%
bronze_folder_path = "abfss://bronze@projectmovies.dfs.core.windows.net"
silver_folder_path = "abfss://silver@projectmovies.dfs.core.windows.net"
gold_folder_path = "abfss://gold@projectmovies.dfs.core.windows.net"
