# %%
from pyspark.sql.functions import current_timestamp, lit

def add_columnas_control (input_df, entorno):
    output_df = input_df.withColumn("ingestion_date", current_timestamp())\
                        .withColumn("environment", lit(entorno))
    return output_df
