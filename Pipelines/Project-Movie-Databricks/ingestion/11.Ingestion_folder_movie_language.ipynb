# %% [markdown]
# ### Realizamos la conexion hacia nuestro ADLS por medio de service principal

# %%
# %run ../config/Access_ADLS_Service_Principal

# %%
# %run ../includes/configuration

# %%
# %run ../includes/common_functions

# %%
dbutils.widgets.text("p_environment", "")
v_environment = dbutils.widgets.get("p_environment")

# %% [markdown]
# ### Leemos los archivos json de nuestro contenedor bronze

# %%
from pyspark.sql.types import StructType, StructField, StringType, IntegerType
movie_language_schema = StructType(fields=[
    StructField("movieId", IntegerType(), True),
    StructField("languageId", IntegerType(), True),
    StructField("languageRoleId", IntegerType(), True)
])

# %%
# Se usa el * para definir que cargue todos los archivos que se llamen production_company
df = spark.read \
    .schema(movie_language_schema) \
    .option("multiline", True) \
    .json(f"{bronze_folder_path}/movie_language")

# %% [markdown]
# ###### Borramos las columnas que no utilizaremos

# %%
df_drop = df.drop("languageRoleId")

# %% [markdown]
# ###### Cambiamos el nombre de las columnas

# %%
df_renamed = df_drop.withColumnRenamed("movieId", "movie_id")\
                    .withColumnRenamed("languageId", "language_id")

# %% [markdown]
# ###### Adiccionamos dos nuevas columnas, una para guardar la fecha de ingestion y la otra para guardar el ambiente

# %%
df_add = add_columnas_control(df_renamed,v_environment)

# %% [markdown]
# ###### Escribimos los datos en nuestro contenedor silver del data lake

# %%
df_add.write.mode("overwrite").parquet(f"{silver_folder_path}/movie_language")
