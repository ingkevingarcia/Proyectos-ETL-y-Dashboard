# %% [markdown]
# ### Realizamos la conexion hacia nuestro ADLS por medio de service principal

# %%
# %run ../config/Access_ADLS_Service_Principal

# %%
# %run ../includes/configuration

# %%
# %run ../includes/common_functions

# %%
dbutils.widgets.text("p_environment", "")
v_environment = dbutils.widgets.get("p_environment")

# %% [markdown]
# ### Leemos el archivo language_role.json de nuestro contenedor bronze

# %%
from pyspark.sql.types import StructType, StructField, StringType, IntegerType
language_role_schema = StructType(fields=[
    StructField("roleId", IntegerType(), True),
    StructField("languageRole", StringType(), True),
])

# %%
df = spark.read \
    .schema(language_role_schema) \
    .option("multiline", True) \
    .json(f"{bronze_folder_path}/language_role.json")

# %% [markdown]
# ###### Cambiamos el nombre de las columnas

# %%
from pyspark.sql.functions import col,current_timestamp, lit

df_renamed = df.withColumnRenamed("roleId", "role_id")\
                        .withColumnRenamed("languageRole", "language_role")

# %% [markdown]
# ###### Adiccionamos dos nuevas columnas, una para guardar la fecha de ingestion y la otra para guardar el ambiente

# %%
df_add = add_columnas_control(df_renamed,v_environment)

# %% [markdown]
# ###### Escribimos los datos en nuestro contenedor silver del data lake

# %%
df_add.write.mode("overwrite").parquet(f"{silver_folder_path}/language_role")
