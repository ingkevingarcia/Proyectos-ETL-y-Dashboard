# %% [markdown]
# ### Realizamos la conexion hacia nuestro ADLS por medio de service principal

# %%
# %run ../config/Access_ADLS_Service_Principal

# %%
# %run ../includes/configuration

# %%
# %run ../includes/common_functions

# %%
dbutils.widgets.text("p_environment", "")
v_environment = dbutils.widgets.get("p_environment")

# %% [markdown]
# ### Leemos el archivo genre.csv de nuestro contenedor bronze

# %%
df = spark.read.option("header", "true")\
          .option("inferSchema", "true")\
          .csv(f"{bronze_folder_path}/genre.csv")

# %% [markdown]
# ###### Cambiamos el nombre de las columnas

# %%
df_renamed = df.withColumnRenamed("genreId", "genre_id")\
                        .withColumnRenamed("genreName", "genre_name")

# %% [markdown]
# ###### Adiccionamos dos nuevas columnas, una para guardar la fecha de ingestion y la otra para guardar el ambiente

# %%
df_add = add_columnas_control(df_renamed,v_environment)

# %% [markdown]
# ###### Escribimos los datos en nuestro contenedor silver de ADLS

# %%
df_add.write.mode("overwrite").parquet(f"{silver_folder_path}/genre")
